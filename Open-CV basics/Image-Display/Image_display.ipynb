# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np

# %%
import cv2 

input = cv2.imread('F:\ScoutOP.jpg')

plt.imshow(cv2.cvtColor(input, cv2.COLOR_BGR2RGB))
plt.title('SCOUT')

plt.show()

# %%
input.shape
# Out:
# (1024, 1024, 3)

# %%
print ('Height of Image:', int(input.shape[0]), 'pixels')
print ('Width of Image: ', int(input.shape[1]), 'pixels')
# Out:
# Height of Image: 1024 pixels
# Width of Image:  1024 pixels

# %%
cv2.imwrite('ScoutOP.jpg', input)
cv2.imwrite('ScoutOP.png', input)
# Out:
# True
